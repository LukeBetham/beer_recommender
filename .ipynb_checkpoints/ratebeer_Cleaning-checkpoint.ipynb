# %%
import pandas as pd
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas
from geopy.geocoders import Nominatim

# %% [markdown]
# ## Geotagging the scraped Data

# %%
df = pd.read_csv('all_reviews.csv')
locations_df = pd.read_csv('locations_geotagged.csv')
beer_df = pd.read_csv('beer_deets.csv')

# %%
df
# Out:
#                                              beer_name  beer_rating  \
# 0                             St. Peter's Ruby Red Ale          3.3
# 1                     Shepherd Neame Spitfire (Bottle)          2.2
# 2                                      Arbor Rocketman          3.8
# 3               Shepherd Neame India Pale Ale (Bottle)          3.4
# 4                         Shepherd Neame Christmas Ale          3.3
# ...                                                ...          ...
# 29073                                 Miller High Life          4.0
# 29074                           New Glarus Spotted Cow          4.7
# 29075  Vibrant Forest Stone Sap - Juicy India Pale Ale          1.9
# 29076                                McEwan's Champion          5.0
# 29077                       Leelanau Petoskey Pale Ale          1.6
#
#                brewery_location  \
# 0               Bungay, Suffolk
# 1               Faversham, Kent
# 2      Bristol, Gloucestershire
# 3               Faversham, Kent
# 4               Faversham, Kent
# ...                         ...
# 29073                      +2.3
# 29074                      +1.6
# 29075                      -1.6
# 29076                      +1.7
# 29077                        -2
#
#                                           brewery_name  \
# 0                                  St. Peter's Brewery
# 1                                       Shepherd Neame
# 2                                           Arbor Ales
# 3                                       Shepherd Neame
# 4                                       Shepherd Neame
# ...                                                ...
# 29073            Miller Brewing Company (Molson Coors)
# 29074                       New Glarus Brewing Company
# 29075                           Vibrant Forest Brewery
# 29076  Eagle Brewery (Carlsberg Marston's Brewing Co.)
# 29077                         Leelanau Brewing Company
#
#                                           review_content        reviewer_name
# 0      Ruby color, offwhite coam. Aroma and taste: fl...            alex_leit
# 1      Disappointing show from the lads at ‘Britain’s...  shivermetimber.gray
# 2      Puszka. Mętne o żółtym kolorze. Piana biała,ob...              MarcinG
# 3      Bottle. Amber with bronze color and white foam...            alex_leit
# 4      Bottle. Aroma: English hops and malts with tof...            alex_leit
# ...                                                  ...                  ...
# 29073  People can trash this beer all they want, but ...               moomin
# 29074  A classic delicious Wisconsin beer, maybe my f...               moomin
# 29075  Mętne z dużą ilością goryczki, która przerasta...                torrc
# 29076  Bought this beer from Tesco superstore in Nott...              ng51guy
# 29077  Surprised I haven’t rated this. This was a 201...          PhillyCraft
#
# [29078 rows x 6 columns]

# %%
locations_df
# Out:
#                             locations   latitude  longitude  \
# 0                     Bungay, Suffolk  52.456225   1.437341
# 1                     Faversham, Kent  51.314409   0.891189
# 2            Bristol, Gloucestershire  51.852767  -2.255369
# 3                   Round Rock, Texas  30.508235 -97.678893
# 4                  Brooklyn, New York  40.650104 -73.949582
# ...                               ...        ...        ...
# 2376                  Kettering, Ohio  39.689504 -84.168827
# 2377          Jersey City, New Jersey  40.728158 -74.077642
# 2378              Hoboken, New Jersey  40.743307 -74.032375
# 2379           London, Greater London  51.507322  -0.127647
# 2380  Krefeld, North Rhine-Westphalia  51.333120   6.562334
#
#                        country
# 0               United Kingdom
# 1               United Kingdom
# 2               United Kingdom
# 3     United States of America
# 4     United States of America
# ...                        ...
# 2376  United States of America
# 2377  United States of America
# 2378  United States of America
# 2379            United Kingdom
# 2380                   Germany
#
# [2381 rows x 4 columns]

# %%
geolocator = Nominatim(user_agent="None")

# %%
locations_new = pd.DataFrame(df.brewery_location[~df.brewery_location.isin(locations_df.locations)].unique(),columns=['locations'])
print(len(locations_new), "new locations to search for! Will take", len(locations_new)/2, "seconds to run.")
# Out:
# 19 new locations to search for! Will take 9.5 seconds to run.

# %%
def tryconvert(x):
        try:
            return geolocator.geocode(x).latitude
        except:
            return None

# %%
def tryconvertlong(x):
        try:
            return geolocator.geocode(x).longitude
        except:
            return None

# %%
locations_new["latitude"] = locations_new.locations.apply(lambda x: tryconvert(x))

# %%
locations_new["longitude"] = locations_new.locations.apply(lambda x: tryconvertlong(x))

# %%
countries = []
for row in locations_new.index:
    try:
        loc = geolocator.reverse([locations_new.iloc[row,1],locations_new.iloc[row,2]], language='en')
        countries.append(loc.raw['address']['country'])
    except:
        countries.append(None)

# %%
locations_new['country'] = countries

# %%
locations_new
# Out:
#                          locations   latitude   longitude  \
# 0   West Kelowna, British Columbia  49.857464 -119.580688
# 1        Merritt, British Columbia  50.111704 -120.788423
# 2         Chesham, Buckinghamshire  51.706291   -0.612311
# 3         Wallingford, Connecticut  41.457042  -72.823155
# 4                     Kalona, Iowa  41.483072  -91.706002
# 5                 Laurel, Maryland  39.099275  -76.848306
# 6                Maria Stein, Ohio  40.407825  -84.493286
# 7       West Reading, Pennsylvania  40.333704  -75.947432
# 8               Brantford, Ontario  43.140816  -80.263173
# 9           Berchtesgaden, Bavaria  47.631080   13.002163
# 10              Memmingen, Bavaria  47.986770   10.181319
# 11        Kiel, Schleswig-Holstein  54.322708   10.135555
# 12     Philadelphia , Pennsylvania  39.952724  -75.163526
# 13            Free Union, Virginia  38.154856  -78.564459
# 14     North Little Rock, Arkansas  34.769536  -92.267094
# 15           Au/Hallertau, Bavaria  48.558563   11.737841
# 16          Reisbach/Vils, Bavaria        NaN         NaN
# 17              Columbia, Missouri  38.951883  -92.333737
# 18          Safety Harbor, Florida  27.990853  -82.693155
#
#                      country
# 0                     Canada
# 1                     Canada
# 2             United Kingdom
# 3   United States of America
# 4   United States of America
# 5   United States of America
# 6   United States of America
# 7   United States of America
# 8                     Canada
# 9                    Germany
# 10                   Germany
# 11                   Germany
# 12  United States of America
# 13  United States of America
# 14  United States of America
# 15                   Germany
# 16                      None
# 17  United States of America
# 18  United States of America

# %%
locations_df = pd.concat([locations_df,locations_new])
locations_df.to_csv('locations_geotagged.csv',index=False)

# %% [markdown]
# ## Merging and cleaning

# %%
beer_df
# Out:
#                                            return_string flag  \
# 0      St. Peter's Ruby Red Ale\n🇬🇧 Bitter - Ordinary...   🇬🇧
# 1      Shepherd Neame Spitfire (Bottle)\n🇬🇧 Bitter - ...   🇬🇧
# 2      Arbor Rocketman\n🇬🇧 IPA • 6.0%\n95\n97\n3.74\n...   🇬🇧
# 3      Shepherd Neame India Pale Ale (Bottle)\n🇬🇧 IPA...   🇬🇧
# 4      Shepherd Neame Christmas Ale\n🇬🇧 Strong Ale - ...   🇬🇧
# ...                                                  ...  ...
# 15597  FrauGruber / Sudden Death / BrewHeart All Toge...   🇩🇪
# 15598  Toppling Goliath Pseudo Sue - Citra Double Dry...   🇺🇸
# 15599  Toppling Goliath Light Speed Pale Ale - Double...   🇺🇸
# 15600  Diamond Bear Pig Trail Porter\n🇺🇸 Porter0\n-\n...   🇺🇸
# 15601  Les Trois Mousquetaires Oud Bruin Camerise\n🇨🇦...   🇨🇦
#
#                                type  abv rb_overall_score rb_style_score  \
# 0         Bitter - Ordinary / Best   4.3               49             95
# 1         Bitter - Ordinary / Best   4.5               34             59
# 2                              IPA   6.0               95             97
# 3                    IPA - English   6.1               46             47
# 4             Strong Ale - English   7.0               45             46
# ...                             ...  ...              ...            ...
# 15597           IPA - Hazy / NEIPA   6.5                -              -
# 15598    Pale Ale - American / APA   5.8               99            100
# 15599    Pale Ale - American / APA   6.2               94             98
# 15600                        Porter  0.0                -              -
# 15601   Sour - Flanders Red / Bruin  NaN                -              -
#
#       rb_user_rating  rb_rating_number  \
# 0               3.25             415.0
# 1               3.05            1083.0
# 2               3.74              59.0
# 3               3.22             420.0
# 4               3.18             409.0
# ...              ...               ...
# 15597           3.20               1.0
# 15598           3.98             195.0
# 15599           3.74              25.0
# 15600           3.49              12.0
# 15601           3.80               1.0
#
#                                               name_found
# 0                               St. Peter's Ruby Red Ale
# 1                       Shepherd Neame Spitfire (Bottle)
# 2                                        Arbor Rocketman
# 3                 Shepherd Neame India Pale Ale (Bottle)
# 4                           Shepherd Neame Christmas Ale
# ...                                                  ...
# 15597  FrauGruber / Sudden Death / BrewHeart All Toge...
# 15598  Toppling Goliath Pseudo Sue - Citra Double Dry...
# 15599  Toppling Goliath Light Speed Pale Ale - Double...
# 15600                      Diamond Bear Pig Trail Porter
# 15601         Les Trois Mousquetaires Oud Bruin Camerise
#
# [15602 rows x 9 columns]

# %%
# Creating DF with all details
df_all = pd.merge(df,locations_df,how='left',left_on='brewery_location',right_on='locations')
df_all = pd.merge(df_all, beer_df, how='left', left_on='beer_name',right_on='name_found')
df_all
# Out:
#                                              beer_name  beer_rating  \
# 0                             St. Peter's Ruby Red Ale          3.3
# 1                     Shepherd Neame Spitfire (Bottle)          2.2
# 2                                      Arbor Rocketman          3.8
# 3               Shepherd Neame India Pale Ale (Bottle)          3.4
# 4                         Shepherd Neame Christmas Ale          3.3
# ...                                                ...          ...
# 29351                                 Miller High Life          4.0
# 29352                           New Glarus Spotted Cow          4.7
# 29353  Vibrant Forest Stone Sap - Juicy India Pale Ale          1.9
# 29354                                McEwan's Champion          5.0
# 29355                       Leelanau Petoskey Pale Ale          1.6
#
#                brewery_location  \
# 0               Bungay, Suffolk
# 1               Faversham, Kent
# 2      Bristol, Gloucestershire
# 3               Faversham, Kent
# 4               Faversham, Kent
# ...                         ...
# 29351                      +2.3
# 29352                      +1.6
# 29353                      -1.6
# 29354                      +1.7
# 29355                        -2
#
#                                           brewery_name  \
# 0                                  St. Peter's Brewery
# 1                                       Shepherd Neame
# 2                                           Arbor Ales
# 3                                       Shepherd Neame
# 4                                       Shepherd Neame
# ...                                                ...
# 29351            Miller Brewing Company (Molson Coors)
# 29352                       New Glarus Brewing Company
# 29353                           Vibrant Forest Brewery
# 29354  Eagle Brewery (Carlsberg Marston's Brewing Co.)
# 29355                         Leelanau Brewing Company
#
#                                           review_content        reviewer_name  \
# 0      Ruby color, offwhite coam. Aroma and taste: fl...            alex_leit
# 1      Disappointing show from the lads at ‘Britain’s...  shivermetimber.gray
# 2      Puszka. Mętne o żółtym kolorze. Piana biała,ob...              MarcinG
# 3      Bottle. Amber with bronze color and white foam...            alex_leit
# 4      Bottle. Aroma: English hops and malts with tof...            alex_leit
# ...                                                  ...                  ...
# 29351  People can trash this beer all they want, but ...               moomin
# 29352  A classic delicious Wisconsin beer, maybe my f...               moomin
# 29353  Mętne z dużą ilością goryczki, która przerasta...                torrc
# 29354  Bought this beer from Tesco superstore in Nott...              ng51guy
# 29355  Surprised I haven’t rated this. This was a 201...          PhillyCraft
#
#                       locations   latitude  longitude         country  \
# 0               Bungay, Suffolk  52.456225   1.437341  United Kingdom
# 1               Faversham, Kent  51.314409   0.891189  United Kingdom
# 2      Bristol, Gloucestershire  51.852767  -2.255369  United Kingdom
# 3               Faversham, Kent  51.314409   0.891189  United Kingdom
# 4               Faversham, Kent  51.314409   0.891189  United Kingdom
# ...                         ...        ...        ...             ...
# 29351                      +2.3  51.254303   7.148721         Germany
# 29352                      +1.6  48.718182   9.989251         Germany
# 29353                      -1.6  48.718182   9.989251         Germany
# 29354                      +1.7  48.780313  10.039726         Germany
# 29355                        -2 -23.604131 -69.084278           Chile
#
#                                            return_string flag  \
# 0      St. Peter's Ruby Red Ale\n🇬🇧 Bitter - Ordinary...   🇬🇧
# 1      Shepherd Neame Spitfire (Bottle)\n🇬🇧 Bitter - ...   🇬🇧
# 2      Arbor Rocketman\n🇬🇧 IPA • 6.0%\n95\n97\n3.74\n...   🇬🇧
# 3      Shepherd Neame India Pale Ale (Bottle)\n🇬🇧 IPA...   🇬🇧
# 4      Shepherd Neame Christmas Ale\n🇬🇧 Strong Ale - ...   🇬🇧
# ...                                                  ...  ...
# 29351  Miller High Life\n🇺🇸 Pale Lager - North Am. / ...   🇺🇸
# 29352  New Glarus Spotted Cow\n🇺🇸 Saison / Farmhouse ...   🇺🇸
# 29353  Vibrant Forest Stone Sap - Juicy India Pale Al...   🇬🇧
# 29354  McEwan's Champion\n🇬🇧 Scotch Ale / Wee Heavy •...   🇬🇧
# 29355  Leelanau Petoskey Pale Ale\n🇺🇸 Belgian Ale - P...   🇺🇸
#
#                                           type  abv rb_overall_score  \
# 0                    Bitter - Ordinary / Best   4.3               49
# 1                    Bitter - Ordinary / Best   4.5               34
# 2                                         IPA   6.0               95
# 3                               IPA - English   6.1               46
# 4                        Strong Ale - English   7.0               45
# ...                                        ...  ...              ...
# 29351   Pale Lager - North Am. / Light / Rice   4.6                0
# 29352           Saison / Farmhouse / Grisette   4.9               40
# 29353                      IPA - Hazy / NEIPA   6.8               85
# 29354                  Scotch Ale / Wee Heavy   7.3               55
# 29355             Belgian Ale - Pale / Golden   5.5               93
#
#       rb_style_score rb_user_rating  rb_rating_number  \
# 0                 95           3.25             415.0
# 1                 59           3.05            1083.0
# 2                 97           3.74              59.0
# 3                 47           3.22             420.0
# 4                 46           3.18             409.0
# ...              ...            ...               ...
# 29351              9           1.94            1832.0
# 29352             17           3.30            1107.0
# 29353             47           3.47              33.0
# 29354             41           3.36             320.0
# 29355             99           3.65             150.0
#
#                                             name_found
# 0                             St. Peter's Ruby Red Ale
# 1                     Shepherd Neame Spitfire (Bottle)
# 2                                      Arbor Rocketman
# 3               Shepherd Neame India Pale Ale (Bottle)
# 4                         Shepherd Neame Christmas Ale
# ...                                                ...
# 29351                                 Miller High Life
# 29352                           New Glarus Spotted Cow
# 29353  Vibrant Forest Stone Sap - Juicy India Pale Ale
# 29354                                McEwan's Champion
# 29355                       Leelanau Petoskey Pale Ale
#
# [29356 rows x 19 columns]

# %%
# drop excess columns
df_all.drop(["locations","return_string","name_found"],axis=1,inplace=True)
# drop rows with ratings instead of location
df_all = df_all[~df_all['brewery_location'].str.len()<4]
# drop all NaNs
print(len(df_all) - len(df_all.dropna()), "columns with NaNs dropped.")
df_all.dropna(inplace=True)
# Out:
# 2195 columns with NaNs dropped.

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27161 entries, 0 to 29355
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   beer_name         27161 non-null  object
#  1   beer_rating       27161 non-null  float64
#  2   brewery_location  27161 non-null  object
#  3   brewery_name      27161 non-null  object
#  4   review_content    27161 non-null  object
#  5   reviewer_name     27161 non-null  object
#  6   latitude          27161 non-null  float64
#  7   longitude         27161 non-null  float64
#  8   country           27161 non-null  object
#  9   flag              27161 non-null  object
#  10  type              27161 non-null  object
#  11  abv               27161 non-null  float64
#  12  rb_overall_score  27161 non-null  object
#  13  rb_style_score    27161 non-null  object
#  14  rb_user_rating    27161 non-null  object
#  15  rb_rating_number  27161 non-null  float64
# dtypes: float64(5), object(11)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Deal with Non-English Descriptions

# %% [markdown]
# ## Save down cleaned data

# %%
df_all.to_csv("data_clean.csv",index=False)
