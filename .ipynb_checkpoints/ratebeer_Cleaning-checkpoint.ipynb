# %%
import pandas as pd
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas
from geopy.geocoders import Nominatim

# %% [markdown]
# ## Geotagging the scraped Data

# %%
df = pd.read_csv('all_reviews.csv')
locations_df = pd.read_csv('locations_geotagged.csv')
beer_df = pd.read_csv('beer_deets.csv')

# %%
df
# Out:
#                                     beer_name  beer_rating  \
# 0                    St. Peter's Ruby Red Ale          3.3
# 1            Shepherd Neame Spitfire (Bottle)          2.2
# 2                             Arbor Rocketman          3.8
# 3      Shepherd Neame India Pale Ale (Bottle)          3.4
# 4                Shepherd Neame Christmas Ale          3.3
# ...                                       ...          ...
# 29076              Leelanau Petoskey Pale Ale          1.6
# 29077                                Heineken          4.2
# 29078                       Taurus Pear Cider          5.0
# 29079                       Taurus Dark Fruit          5.0
# 29080     Great Lakes Ohio City Oatmeal Stout          1.7
#
#                brewery_location                brewery_name  \
# 0               Bungay, Suffolk         St. Peter's Brewery
# 1               Faversham, Kent              Shepherd Neame
# 2      Bristol, Gloucestershire                  Arbor Ales
# 3               Faversham, Kent              Shepherd Neame
# 4               Faversham, Kent              Shepherd Neame
# ...                         ...                         ...
# 29076                        -2    Leelanau Brewing Company
# 29077                      +2.1          Heineken Nederland
# 29078                      +2.4                   Aldi (UK)
# 29079                      +2.5                   Aldi (UK)
# 29080                      -1.8  Great Lakes Brewing (Ohio)
#
#                                           review_content        reviewer_name
# 0      Ruby color, offwhite coam. Aroma and taste: fl...            alex_leit
# 1      Disappointing show from the lads at ‘Britain’s...  shivermetimber.gray
# 2      Puszka. Mętne o żółtym kolorze. Piana biała,ob...              MarcinG
# 3      Bottle. Amber with bronze color and white foam...            alex_leit
# 4      Bottle. Aroma: English hops and malts with tof...            alex_leit
# ...                                                  ...                  ...
# 29076  Surprised I haven’t rated this. This was a 201...          PhillyCraft
# 29077  Cerveja levemente amarga, mas suave. Não beber...        leonardocouto
# 29078  Taurus, Taurus, Taurus that is my life now, I ...      PilsnerGuide144
# 29079  I am a consistent Taurus drinker ! I have Taur...      PilsnerGuide144
# 29080  This just tastes funny. Sort of a watery, kind...           EvanFriend
#
# [29081 rows x 6 columns]

# %%
locations_df
# Out:
#                      locations   latitude  longitude                   country
# 0              Bungay, Suffolk  52.456225   1.437341            United Kingdom
# 1              Faversham, Kent  51.314409   0.891189            United Kingdom
# 2     Bristol, Gloucestershire  51.852767  -2.255369            United Kingdom
# 3            Round Rock, Texas  30.508235 -97.678893  United States of America
# 4           Brooklyn, New York  40.650104 -73.949582  United States of America
# ...                        ...        ...        ...                       ...
# 2367       Glenville, New York  42.868250 -73.928279  United States of America
# 2368          Hudson, New York  42.252865 -73.790959  United States of America
# 2369     Harvey, New Brunswick  45.729716 -67.007096                    Canada
# 2370       Regensburg, Bavaria  49.019533  12.097487                   Germany
# 2371        Ripley, Derbyshire  53.051518  -1.402631            United Kingdom
#
# [2372 rows x 4 columns]

# %%
geolocator = Nominatim(user_agent="None")

# %%
locations_new = pd.DataFrame(df.brewery_location[~df.brewery_location.isin(locations_df.locations)].unique(),columns=['locations'])
print(len(locations_new), "new locations to search for! Will take", len(locations_new)/2, "seconds to run.")
# Out:
# 9 new locations to search for! Will take 4.5 seconds to run.

# %%
def tryconvert(x):
        try:
            return geolocator.geocode(x).latitude
        except:
            return None

# %%
def tryconvertlong(x):
        try:
            return geolocator.geocode(x).longitude
        except:
            return None

# %%
locations_new["latitude"] = locations_new.locations.apply(lambda x: tryconvert(x))

# %%
locations_new["longitude"] = locations_new.locations.apply(lambda x: tryconvertlong(x))

# %%
countries = []
for row in locations_new.index:
    try:
        loc = geolocator.reverse([locations_new.iloc[row,1],locations_new.iloc[row,2]], language='en')
        countries.append(loc.raw['address']['country'])
    except:
        countries.append(None)

# %%
locations_new['country'] = countries

# %%
locations_new
# Out:
#                          locations   latitude   longitude  \
# 0                 Halfing, Bavaria  47.950043   12.276509
# 1            Buena Vista, Colorado  38.842218 -106.131129
# 2               Enterprise, Oregon  45.425811 -117.278012
# 3         Grass Valley, California  39.219060 -121.061058
# 4                  Kettering, Ohio  39.689504  -84.168827
# 5          Jersey City, New Jersey  40.728158  -74.077642
# 6              Hoboken, New Jersey  40.743307  -74.032375
# 7           London, Greater London  51.507322   -0.127647
# 8  Krefeld, North Rhine-Westphalia  51.333120    6.562334
#
#                     country
# 0                   Germany
# 1  United States of America
# 2  United States of America
# 3  United States of America
# 4  United States of America
# 5  United States of America
# 6  United States of America
# 7            United Kingdom
# 8                   Germany

# %%
locations_df = pd.concat([locations_df,locations_new])
locations_df.to_csv('locations_geotagged.csv',index=False)

# %% [markdown]
# ## Merging and cleaning

# %%
beer_df
# Out:
#                                            return_string flag  \
# 0      St. Peter's Ruby Red Ale\n🇬🇧 Bitter - Ordinary...   🇬🇧
# 1      Shepherd Neame Spitfire (Bottle)\n🇬🇧 Bitter - ...   🇬🇧
# 2      Arbor Rocketman\n🇬🇧 IPA • 6.0%\n95\n97\n3.74\n...   🇬🇧
# 3      Shepherd Neame India Pale Ale (Bottle)\n🇬🇧 IPA...   🇬🇧
# 4      Shepherd Neame Christmas Ale\n🇬🇧 Strong Ale - ...   🇬🇧
# ...                                                  ...  ...
# 15363  Swamp Head Big Nose IPA\n🇺🇸 IPA • 7.3%\n83\n79...   🇺🇸
# 15364  Deciduous / Mortalis Thyrsus\n🇺🇸 Stout - Imper...   🇺🇸
# 15365  Tired Hands Ouriserva\n🇺🇸 Saison / Farmhouse /...   🇺🇸
# 15366  Legal Draft Summer Recess\n🇺🇸 Radler / Shandy0...   🇺🇸
# 15367  Susquehanna Orange is the New Ale\n🇺🇸 Flavored...   🇺🇸
#
#                                   type   abv rb_overall_score rb_style_score  \
# 0            Bitter - Ordinary / Best    4.3               49             95
# 1            Bitter - Ordinary / Best    4.5               34             59
# 2                                 IPA    6.0               95             97
# 3                       IPA - English    6.1               46             47
# 4                Strong Ale - English    7.0               45             46
# ...                                ...   ...              ...            ...
# 15363                             IPA    7.3               83             79
# 15364       Stout - Imperial Flavored   10.0                -              -
# 15365   Saison / Farmhouse / Grisette    4.8                -              -
# 15366                  Radler / Shandy   0.0                -              -
# 15367                 Flavored - Fruit   0.0                -              -
#
#       rb_user_rating  rb_rating_number                              name_found
# 0               3.25             415.0                St. Peter's Ruby Red Ale
# 1               3.05            1083.0        Shepherd Neame Spitfire (Bottle)
# 2               3.74              59.0                         Arbor Rocketman
# 3               3.22             420.0  Shepherd Neame India Pale Ale (Bottle)
# 4               3.18             409.0            Shepherd Neame Christmas Ale
# ...              ...               ...                                     ...
# 15363           3.58             156.0                 Swamp Head Big Nose IPA
# 15364           3.60               1.0            Deciduous / Mortalis Thyrsus
# 15365           3.90               3.0                   Tired Hands Ouriserva
# 15366           3.15               2.0               Legal Draft Summer Recess
# 15367           3.27               3.0       Susquehanna Orange is the New Ale
#
# [15368 rows x 9 columns]

# %%
# Creating DF with all details
df_all = pd.merge(df,locations_df,how='left',left_on='brewery_location',right_on='locations')
df_all = pd.merge(df_all, beer_df, how='left', left_on='beer_name',right_on='name_found')
df_all
# Out:
#                                     beer_name  beer_rating  \
# 0                    St. Peter's Ruby Red Ale          3.3
# 1            Shepherd Neame Spitfire (Bottle)          2.2
# 2                             Arbor Rocketman          3.8
# 3      Shepherd Neame India Pale Ale (Bottle)          3.4
# 4                Shepherd Neame Christmas Ale          3.3
# ...                                       ...          ...
# 29353              Leelanau Petoskey Pale Ale          1.6
# 29354                                Heineken          4.2
# 29355                       Taurus Pear Cider          5.0
# 29356                       Taurus Dark Fruit          5.0
# 29357     Great Lakes Ohio City Oatmeal Stout          1.7
#
#                brewery_location                brewery_name  \
# 0               Bungay, Suffolk         St. Peter's Brewery
# 1               Faversham, Kent              Shepherd Neame
# 2      Bristol, Gloucestershire                  Arbor Ales
# 3               Faversham, Kent              Shepherd Neame
# 4               Faversham, Kent              Shepherd Neame
# ...                         ...                         ...
# 29353                        -2    Leelanau Brewing Company
# 29354                      +2.1          Heineken Nederland
# 29355                      +2.4                   Aldi (UK)
# 29356                      +2.5                   Aldi (UK)
# 29357                      -1.8  Great Lakes Brewing (Ohio)
#
#                                           review_content        reviewer_name  \
# 0      Ruby color, offwhite coam. Aroma and taste: fl...            alex_leit
# 1      Disappointing show from the lads at ‘Britain’s...  shivermetimber.gray
# 2      Puszka. Mętne o żółtym kolorze. Piana biała,ob...              MarcinG
# 3      Bottle. Amber with bronze color and white foam...            alex_leit
# 4      Bottle. Aroma: English hops and malts with tof...            alex_leit
# ...                                                  ...                  ...
# 29353  Surprised I haven’t rated this. This was a 201...          PhillyCraft
# 29354  Cerveja levemente amarga, mas suave. Não beber...        leonardocouto
# 29355  Taurus, Taurus, Taurus that is my life now, I ...      PilsnerGuide144
# 29356  I am a consistent Taurus drinker ! I have Taur...      PilsnerGuide144
# 29357  This just tastes funny. Sort of a watery, kind...           EvanFriend
#
#                       locations   latitude   longitude         country  \
# 0               Bungay, Suffolk  52.456225    1.437341  United Kingdom
# 1               Faversham, Kent  51.314409    0.891189  United Kingdom
# 2      Bristol, Gloucestershire  51.852767   -2.255369  United Kingdom
# 3               Faversham, Kent  51.314409    0.891189  United Kingdom
# 4               Faversham, Kent  51.314409    0.891189  United Kingdom
# ...                         ...        ...         ...             ...
# 29353                        -2 -23.604131  -69.084278           Chile
# 29354                      +2.1  33.814488  130.890462           Japan
# 29355                      +2.4        NaN    9.991238             NaN
# 29356                      +2.5  50.814444   14.361805  Czech Republic
# 29357                      -1.8  48.780981   10.037026         Germany
#
#                                            return_string flag  \
# 0      St. Peter's Ruby Red Ale\n🇬🇧 Bitter - Ordinary...   🇬🇧
# 1      Shepherd Neame Spitfire (Bottle)\n🇬🇧 Bitter - ...   🇬🇧
# 2      Arbor Rocketman\n🇬🇧 IPA • 6.0%\n95\n97\n3.74\n...   🇬🇧
# 3      Shepherd Neame India Pale Ale (Bottle)\n🇬🇧 IPA...   🇬🇧
# 4      Shepherd Neame Christmas Ale\n🇬🇧 Strong Ale - ...   🇬🇧
# ...                                                  ...  ...
# 29353  Leelanau Petoskey Pale Ale\n🇺🇸 Belgian Ale - P...   🇺🇸
# 29354  Heineken\n🇳🇱 Pale Lager - Intl / Premium • 5.0...   🇳🇱
# 29355  Taurus Pear Cider\n🇬🇧 Perry • 5.3%\n-\n-\n3.19...   🇬🇧
# 29356  Taurus Dark Fruit\n🇬🇧 Apple Cider - Flavored •...   🇬🇧
# 29357  Great Lakes Ohio City Oatmeal Stout\n🇺🇸 Stout ...   🇺🇸
#
#                                 type  abv rb_overall_score rb_style_score  \
# 0          Bitter - Ordinary / Best   4.3               49             95
# 1          Bitter - Ordinary / Best   4.5               34             59
# 2                               IPA   6.0               95             97
# 3                     IPA - English   6.1               46             47
# 4              Strong Ale - English   7.0               45             46
# ...                              ...  ...              ...            ...
# 29353   Belgian Ale - Pale / Golden   5.5               93             99
# 29354   Pale Lager - Intl / Premium   5.0                3             10
# 29355                         Perry   5.3                -              -
# 29356        Apple Cider - Flavored   4.0                -              -
# 29357               Stout - Oatmeal   5.4               84             69
#
#       rb_user_rating  rb_rating_number                              name_found
# 0               3.25             415.0                St. Peter's Ruby Red Ale
# 1               3.05            1083.0        Shepherd Neame Spitfire (Bottle)
# 2               3.74              59.0                         Arbor Rocketman
# 3               3.22             420.0  Shepherd Neame India Pale Ale (Bottle)
# 4               3.18             409.0            Shepherd Neame Christmas Ale
# ...              ...               ...                                     ...
# 29353           3.65             150.0              Leelanau Petoskey Pale Ale
# 29354           2.36            3756.0                                Heineken
# 29355           3.19               8.0                       Taurus Pear Cider
# 29356           3.64               5.0                       Taurus Dark Fruit
# 29357           3.49             184.0     Great Lakes Ohio City Oatmeal Stout
#
# [29358 rows x 19 columns]

# %%
# drop excess columns
df_all.drop(["locations","return_string","name_found"],axis=1,inplace=True)
# drop rows with ratings instead of location
df_all = df_all[~df_all['brewery_location'].str.len()<4]
# drop all NaNs
print(len(df_all) - len(df_all.dropna()), "columns with NaNs dropped.")
df_all.dropna(inplace=True)
# Out:
# 2206 columns with NaNs dropped.

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27152 entries, 0 to 29357
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   beer_name         27152 non-null  object
#  1   beer_rating       27152 non-null  float64
#  2   brewery_location  27152 non-null  object
#  3   brewery_name      27152 non-null  object
#  4   review_content    27152 non-null  object
#  5   reviewer_name     27152 non-null  object
#  6   latitude          27152 non-null  float64
#  7   longitude         27152 non-null  float64
#  8   country           27152 non-null  object
#  9   flag              27152 non-null  object
#  10  type              27152 non-null  object
#  11  abv               27152 non-null  float64
#  12  rb_overall_score  27152 non-null  object
#  13  rb_style_score    27152 non-null  object
#  14  rb_user_rating    27152 non-null  object
#  15  rb_rating_number  27152 non-null  float64
# dtypes: float64(5), object(11)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Deal with Non-English Descriptions

# %% [markdown]
# ## Save down cleaned data

# %%
df_all.to_csv("data_clean.csv",index=False)
