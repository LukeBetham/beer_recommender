# %%
import pandas as pd
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas
from geopy.geocoders import Nominatim

# %% [markdown]
# ## Geotagging the scraped Data

# %%
df = pd.read_csv('all_reviews.csv')
locations_df = pd.read_csv('locations_geotagged.csv')
beer_df = pd.read_csv('beer_deets.csv')

# %%
df
# Out:
#                                     beer_name  beer_rating  \
# 0                    St. Peter's Ruby Red Ale          3.3
# 1            Shepherd Neame Spitfire (Bottle)          2.2
# 2                             Arbor Rocketman          3.8
# 3      Shepherd Neame India Pale Ale (Bottle)          3.4
# 4                Shepherd Neame Christmas Ale          3.3
# ...                                       ...          ...
# 28141                                Heineken          4.2
# 28142                       Taurus Pear Cider          5.0
# 28143                       Taurus Dark Fruit          5.0
# 28144     Great Lakes Ohio City Oatmeal Stout          1.7
# 28145                  Oakham Green Devil IPA          1.5
#
#                brewery_location                brewery_name  \
# 0               Bungay, Suffolk         St. Peter's Brewery
# 1               Faversham, Kent              Shepherd Neame
# 2      Bristol, Gloucestershire                  Arbor Ales
# 3               Faversham, Kent              Shepherd Neame
# 4               Faversham, Kent              Shepherd Neame
# ...                         ...                         ...
# 28141                      +2.1          Heineken Nederland
# 28142                      +2.4                   Aldi (UK)
# 28143                      +2.5                   Aldi (UK)
# 28144                      -1.8  Great Lakes Brewing (Ohio)
# 28145                      -2.2                 Oakham Ales
#
#                                           review_content        reviewer_name
# 0      Ruby color, offwhite coam. Aroma and taste: fl...            alex_leit
# 1      Disappointing show from the lads at ‘Britain’s...  shivermetimber.gray
# 2      Puszka. Mętne o żółtym kolorze. Piana biała,ob...              MarcinG
# 3      Bottle. Amber with bronze color and white foam...            alex_leit
# 4      Bottle. Aroma: English hops and malts with tof...            alex_leit
# ...                                                  ...                  ...
# 28141  Cerveja levemente amarga, mas suave. Não beber...        leonardocouto
# 28142  Taurus, Taurus, Taurus that is my life now, I ...      PilsnerGuide144
# 28143  I am a consistent Taurus drinker ! I have Taur...      PilsnerGuide144
# 28144  This just tastes funny. Sort of a watery, kind...           EvanFriend
# 28145  Was on offer in the local so tried it. This is...        SampleScout19
#
# [28146 rows x 6 columns]

# %%
locations_df
# Out:
#                      locations   latitude  longitude                   country
# 0              Bungay, Suffolk  52.456225   1.437341            United Kingdom
# 1              Faversham, Kent  51.314409   0.891189            United Kingdom
# 2     Bristol, Gloucestershire  51.852767  -2.255369            United Kingdom
# 3            Round Rock, Texas  30.508235 -97.678893  United States of America
# 4           Brooklyn, New York  40.650104 -73.949582  United States of America
# ...                        ...        ...        ...                       ...
# 2346       Rockville, Virginia  39.621471 -79.704774  United States of America
# 2347           Axberg, Austria  46.953826  15.760800                   Austria
# 2348       Royal Oak, Michigan  42.489480 -83.144649  United States of America
# 2349         Bécancour, Quebec  46.339343 -72.433205                    Canada
# 2350        Penzance, Cornwall  50.121317  -5.532927            United Kingdom
#
# [2351 rows x 4 columns]

# %%
geolocator = Nominatim(user_agent="None")

# %%
locations_new = pd.DataFrame(df.brewery_location[~df.brewery_location.isin(locations_df.locations)].unique(),columns=['locations'])
print(len(locations_new), "new locations to search for! Will take", len(locations_new)/2, "seconds to run.")
# Out:
# 21 new locations to search for! Will take 10.5 seconds to run.

# %%
def tryconvert(x):
        try:
            return geolocator.geocode(x).latitude
        except:
            return None

# %%
def tryconvertlong(x):
        try:
            return geolocator.geocode(x).longitude
        except:
            return None

# %%
locations_new["latitude"] = locations_new.locations.apply(lambda x: tryconvert(x))

# %%
locations_new["longitude"] = locations_new.locations.apply(lambda x: tryconvertlong(x))

# %%
countries = []
for row in locations_new.index:
    try:
        loc = geolocator.reverse([locations_new.iloc[row,1],locations_new.iloc[row,2]], language='en')
        countries.append(loc.raw['address']['country'])
    except:
        countries.append(None)

# %%
locations_new['country'] = countries

# %%
locations_new
# Out:
#                            locations   latitude   longitude  \
# 0       Untersiemau-Birkach, Bavaria  50.165451   11.007970
# 1                LaFayette, New York  42.892289  -76.105202
# 2                        Ogden, Utah  41.223005 -111.973843
# 3               Clermont, New Jersey  39.990668  -74.799607
# 4          Sechelt, British Columbia  49.472115 -123.763124
# 5            Little Current, Ontario  45.980049  -81.926799
# 6                 New City, New York  41.149983  -73.989898
# 7           Pennigsehl, Lower Saxony  52.644061    9.027508
# 8               Excelsior, Minnesota  44.903296  -93.566345
# 9   Lübbecke, North Rhine-Westphalia  52.302721    8.618305
# 10         Todmorden, West Yorkshire  53.709960   -2.103706
# 11               Cadolzburg, Bavaria  49.459141   10.856387
# 12                     Pinhoe, Devon  50.737793   -3.470085
# 13                  Sanford, Florida  28.811730  -81.268034
# 14              Meiningen, Thuringia  50.567869   10.415743
# 15              Issaquah, Washington  47.534878 -122.043297
# 16               Glenville, New York  42.868250  -73.928279
# 17                  Hudson, New York  42.252865  -73.790959
# 18             Harvey, New Brunswick  45.729716  -67.007096
# 19               Regensburg, Bavaria  49.019533   12.097487
# 20                Ripley, Derbyshire  53.051518   -1.402631
#
#                      country
# 0                    Germany
# 1   United States of America
# 2   United States of America
# 3   United States of America
# 4                     Canada
# 5                     Canada
# 6   United States of America
# 7                    Germany
# 8   United States of America
# 9                    Germany
# 10            United Kingdom
# 11                   Germany
# 12            United Kingdom
# 13  United States of America
# 14                   Germany
# 15  United States of America
# 16  United States of America
# 17  United States of America
# 18                    Canada
# 19                   Germany
# 20            United Kingdom

# %%
locations_df = pd.concat([locations_df,locations_new])
locations_df.to_csv('locations_geotagged.csv',index=False)

# %% [markdown]
# ## Merging and cleaning

# %%
beer_df
# Out:
#                                            return_string flag  \
# 0      St. Peter's Ruby Red Ale\n🇬🇧 Bitter - Ordinary...   🇬🇧
# 1      Shepherd Neame Spitfire (Bottle)\n🇬🇧 Bitter - ...   🇬🇧
# 2      Arbor Rocketman\n🇬🇧 IPA • 6.0%\n95\n97\n3.74\n...   🇬🇧
# 3      Shepherd Neame India Pale Ale (Bottle)\n🇬🇧 IPA...   🇬🇧
# 4      Shepherd Neame Christmas Ale\n🇬🇧 Strong Ale - ...   🇬🇧
# ...                                                  ...  ...
# 15129  Cycle Snickerdoodle Dandy DOS\n🇺🇸 Stout - Impe...   🇺🇸
# 15130  Block 15 Wellspring\n🇺🇸 Belgian Ale - Pale / G...   🇺🇸
# 15131  Tree House Curiosity 96 (Ninety-Six)\n🇺🇸 IIPA ...   🇺🇸
# 15132  Sommerbecker Dachs Pils\n🇩🇪 Pilsener / Pils / ...   🇩🇪
# 15133  Zötler Hefe-Weizen Alkoholfrei\n🇩🇪 Low / No Al...   🇩🇪
#
#                                      type  abv rb_overall_score  \
# 0               Bitter - Ordinary / Best   4.3               49
# 1               Bitter - Ordinary / Best   4.5               34
# 2                                    IPA   6.0               95
# 3                          IPA - English   6.1               46
# 4                   Strong Ale - English   7.0               45
# ...                                   ...  ...              ...
# 15129           Stout - Imperial Flavored  NaN                -
# 15130         Belgian Ale - Pale / Golden  NaN                -
# 15131   IIPA DIPA - Imperial / Double IPA  NaN                -
# 15132           Pilsener / Pils / Pilsner  0.0               17
# 15133        Low / No Alcohol Beer - Pale  0.0                3
#
#       rb_style_score rb_user_rating  rb_rating_number  \
# 0                 95           3.25             415.0
# 1                 59           3.05            1083.0
# 2                 97           3.74              59.0
# 3                 47           3.22             420.0
# 4                 46           3.18             409.0
# ...              ...            ...               ...
# 15129              -           4.00               1.0
# 15130              -           3.60               1.0
# 15131              -           4.00               1.0
# 15132             41           2.92              14.0
# 15133             45           2.05              39.0
#
#                                    name_found
# 0                    St. Peter's Ruby Red Ale
# 1            Shepherd Neame Spitfire (Bottle)
# 2                             Arbor Rocketman
# 3      Shepherd Neame India Pale Ale (Bottle)
# 4                Shepherd Neame Christmas Ale
# ...                                       ...
# 15129           Cycle Snickerdoodle Dandy DOS
# 15130                     Block 15 Wellspring
# 15131    Tree House Curiosity 96 (Ninety-Six)
# 15132                 Sommerbecker Dachs Pils
# 15133          Zötler Hefe-Weizen Alkoholfrei
#
# [15134 rows x 9 columns]

# %%
# Creating DF with all details
df_all = pd.merge(df,locations_df,how='left',left_on='brewery_location',right_on='locations')
df_all = pd.merge(df_all, beer_df, how='left', left_on='beer_name',right_on='name_found')
df_all
# Out:
#                                     beer_name  beer_rating  \
# 0                    St. Peter's Ruby Red Ale          3.3
# 1            Shepherd Neame Spitfire (Bottle)          2.2
# 2                             Arbor Rocketman          3.8
# 3      Shepherd Neame India Pale Ale (Bottle)          3.4
# 4                Shepherd Neame Christmas Ale          3.3
# ...                                       ...          ...
# 28414                                Heineken          4.2
# 28415                       Taurus Pear Cider          5.0
# 28416                       Taurus Dark Fruit          5.0
# 28417     Great Lakes Ohio City Oatmeal Stout          1.7
# 28418                  Oakham Green Devil IPA          1.5
#
#                brewery_location                brewery_name  \
# 0               Bungay, Suffolk         St. Peter's Brewery
# 1               Faversham, Kent              Shepherd Neame
# 2      Bristol, Gloucestershire                  Arbor Ales
# 3               Faversham, Kent              Shepherd Neame
# 4               Faversham, Kent              Shepherd Neame
# ...                         ...                         ...
# 28414                      +2.1          Heineken Nederland
# 28415                      +2.4                   Aldi (UK)
# 28416                      +2.5                   Aldi (UK)
# 28417                      -1.8  Great Lakes Brewing (Ohio)
# 28418                      -2.2                 Oakham Ales
#
#                                           review_content        reviewer_name  \
# 0      Ruby color, offwhite coam. Aroma and taste: fl...            alex_leit
# 1      Disappointing show from the lads at ‘Britain’s...  shivermetimber.gray
# 2      Puszka. Mętne o żółtym kolorze. Piana biała,ob...              MarcinG
# 3      Bottle. Amber with bronze color and white foam...            alex_leit
# 4      Bottle. Aroma: English hops and malts with tof...            alex_leit
# ...                                                  ...                  ...
# 28414  Cerveja levemente amarga, mas suave. Não beber...        leonardocouto
# 28415  Taurus, Taurus, Taurus that is my life now, I ...      PilsnerGuide144
# 28416  I am a consistent Taurus drinker ! I have Taur...      PilsnerGuide144
# 28417  This just tastes funny. Sort of a watery, kind...           EvanFriend
# 28418  Was on offer in the local so tried it. This is...        SampleScout19
#
#                       locations   latitude   longitude         country  \
# 0               Bungay, Suffolk  52.456225    1.437341  United Kingdom
# 1               Faversham, Kent  51.314409    0.891189  United Kingdom
# 2      Bristol, Gloucestershire  51.852767   -2.255369  United Kingdom
# 3               Faversham, Kent  51.314409    0.891189  United Kingdom
# 4               Faversham, Kent  51.314409    0.891189  United Kingdom
# ...                         ...        ...         ...             ...
# 28414                      +2.1  33.814488  130.890462           Japan
# 28415                      +2.4        NaN    9.991238             NaN
# 28416                      +2.5  50.814444   14.361805  Czech Republic
# 28417                      -1.8  48.780981   10.037026         Germany
# 28418                      -2.2  48.793281    9.967117         Germany
#
#                                            return_string flag  \
# 0      St. Peter's Ruby Red Ale\n🇬🇧 Bitter - Ordinary...   🇬🇧
# 1      Shepherd Neame Spitfire (Bottle)\n🇬🇧 Bitter - ...   🇬🇧
# 2      Arbor Rocketman\n🇬🇧 IPA • 6.0%\n95\n97\n3.74\n...   🇬🇧
# 3      Shepherd Neame India Pale Ale (Bottle)\n🇬🇧 IPA...   🇬🇧
# 4      Shepherd Neame Christmas Ale\n🇬🇧 Strong Ale - ...   🇬🇧
# ...                                                  ...  ...
# 28414  Heineken\n🇳🇱 Pale Lager - Intl / Premium • 5.0...   🇳🇱
# 28415  Taurus Pear Cider\n🇬🇧 Perry • 5.3%\n-\n-\n3.19...   🇬🇧
# 28416  Taurus Dark Fruit\n🇬🇧 Apple Cider - Flavored •...   🇬🇧
# 28417  Great Lakes Ohio City Oatmeal Stout\n🇺🇸 Stout ...   🇺🇸
# 28418  Oakham Green Devil IPA\n🇬🇧 IPA • 6.0%\n96\n97\...   🇬🇧
#
#                                 type  abv rb_overall_score rb_style_score  \
# 0          Bitter - Ordinary / Best   4.3               49             95
# 1          Bitter - Ordinary / Best   4.5               34             59
# 2                               IPA   6.0               95             97
# 3                     IPA - English   6.1               46             47
# 4              Strong Ale - English   7.0               45             46
# ...                              ...  ...              ...            ...
# 28414   Pale Lager - Intl / Premium   5.0                3             10
# 28415                         Perry   5.3                -              -
# 28416        Apple Cider - Flavored   4.0                -              -
# 28417               Stout - Oatmeal   5.4               84             69
# 28418                           IPA   6.0               96             97
#
#       rb_user_rating  rb_rating_number                              name_found
# 0               3.25             415.0                St. Peter's Ruby Red Ale
# 1               3.05            1083.0        Shepherd Neame Spitfire (Bottle)
# 2               3.74              59.0                         Arbor Rocketman
# 3               3.22             420.0  Shepherd Neame India Pale Ale (Bottle)
# 4               3.18             409.0            Shepherd Neame Christmas Ale
# ...              ...               ...                                     ...
# 28414           2.36            3756.0                                Heineken
# 28415           3.19               8.0                       Taurus Pear Cider
# 28416           3.64               5.0                       Taurus Dark Fruit
# 28417           3.49             184.0     Great Lakes Ohio City Oatmeal Stout
# 28418           3.78             435.0                  Oakham Green Devil IPA
#
# [28419 rows x 19 columns]

# %%
# drop excess columns
df_all.drop(["locations","return_string","name_found"],axis=1,inplace=True)
# drop rows with ratings instead of location
df_all = df_all[~df_all['brewery_location'].str.len()<4]
# drop all NaNs
print(len(df_all) - len(df_all.dropna()), "columns with NaNs dropped.")
df_all.dropna(inplace=True)
# Out:
# 2169 columns with NaNs dropped.

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26250 entries, 0 to 28418
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   beer_name         26250 non-null  object
#  1   beer_rating       26250 non-null  float64
#  2   brewery_location  26250 non-null  object
#  3   brewery_name      26250 non-null  object
#  4   review_content    26250 non-null  object
#  5   reviewer_name     26250 non-null  object
#  6   latitude          26250 non-null  float64
#  7   longitude         26250 non-null  float64
#  8   country           26250 non-null  object
#  9   flag              26250 non-null  object
#  10  type              26250 non-null  object
#  11  abv               26250 non-null  float64
#  12  rb_overall_score  26250 non-null  object
#  13  rb_style_score    26250 non-null  object
#  14  rb_user_rating    26250 non-null  object
#  15  rb_rating_number  26250 non-null  float64
# dtypes: float64(5), object(11)
# memory usage: 3.4+ MB

# %% [markdown]
# ## Deal with Non-English Descriptions

# %% [markdown]
# ## Save down cleaned data

# %%
df_all.to_csv("data_clean.csv",index=False)
