# %%
import pandas as pd
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas
from geopy.geocoders import Nominatim

# %% [markdown]
# ## Geotagging the scraped Data

# %%
df = pd.read_csv('all_reviews.csv')
locations_df = pd.read_csv('locations_geotagged.csv')
beer_df = pd.read_csv('beer_deets.csv')

# %%
df
# Out:
#                                         beer_name  beer_rating  \
# 0                        St. Peter's Ruby Red Ale          3.3
# 1                Shepherd Neame Spitfire (Bottle)          2.2
# 2                                 Arbor Rocketman          3.8
# 3          Shepherd Neame India Pale Ale (Bottle)          3.4
# 4                    Shepherd Neame Christmas Ale          3.3
# ...                                           ...          ...
# 23734                 Dogfish Head 120 Minute IPA          1.5
# 23735  Lagunitas Newcastle Brown Ale (US version)          1.0
# 23736                     Samuel Smiths India Ale          1.8
# 23737                       Big Smoke Cosmic Dawn          0.5
# 23738                           Bath Gem (Bottle)          1.6
#
#                brewery_location                            brewery_name  \
# 0               Bungay, Suffolk                     St. Peter's Brewery
# 1               Faversham, Kent                          Shepherd Neame
# 2      Bristol, Gloucestershire                              Arbor Ales
# 3               Faversham, Kent                          Shepherd Neame
# 4               Faversham, Kent                          Shepherd Neame
# ...                         ...                                     ...
# 23734                      -2.4  Dogfish Head Brewery (Boston Beer Co.)
# 23735                      -1.7    Lagunitas Brewing Company (Heineken)
# 23736                      -1.6                            Samuel Smith
# 23737                      -2.5                      Big Smoke Brew Co.
# 23738                      -1.5                 Bath Ales (St. Austell)
#
#                                           review_content        reviewer_name
# 0      Ruby color, offwhite coam. Aroma and taste: fl...            alex_leit
# 1      Disappointing show from the lads at ‘Britain’s...  shivermetimber.gray
# 2      Puszka. Mętne o żółtym kolorze. Piana biała,ob...              MarcinG
# 3      Bottle. Amber with bronze color and white foam...            alex_leit
# 4      Bottle. Aroma: English hops and malts with tof...            alex_leit
# ...                                                  ...                  ...
# 23734  0,3 litre Bottle from Total Wine And More, Lag...          ChrisOfstad
# 23735  Bottle from BevMo, Oceanside, Ca. Why is this ...          ChrisOfstad
# 23736  Bought Nov 8, 2019, at 'Gastronom', Izhevsk, R...             PastorGL
# 23737  On cask at Euston Tap. clear gold colour lasti...            harrisoni
# 23738  500ml bottle in 2015. I don’t know quite what ...                Beese
#
# [23739 rows x 6 columns]

# %%
locations_df
# Out:
#                      locations   latitude  longitude                   country
# 0              Bungay, Suffolk  52.456225   1.437341            United Kingdom
# 1              Faversham, Kent  51.314409   0.891189            United Kingdom
# 2     Bristol, Gloucestershire  51.852767  -2.255369            United Kingdom
# 3            Round Rock, Texas  30.508235 -97.678893  United States of America
# 4           Brooklyn, New York  40.650104 -73.949582  United States of America
# ...                        ...        ...        ...                       ...
# 2154  Carrboro, North Carolina  35.910144 -79.075289  United States of America
# 2155          Yelverton, Devon  50.492942  -4.084674            United Kingdom
# 2156      Panama City, Florida  30.160083 -85.654573  United States of America
# 2157                Bow, Devon  50.801021  -3.815025            United Kingdom
# 2158    Eagle River, Wisconsin  45.917176 -89.244299  United States of America
#
# [2159 rows x 4 columns]

# %%
geolocator = Nominatim(user_agent="None")

# %%
locations_new = pd.DataFrame(df.brewery_location[~df.brewery_location.isin(locations_df.locations)].unique(),columns=['locations'])
print(len(locations_new), "new locations to search for! Will take", len(locations_new)/2, "seconds to run.")
# Out:
# 26 new locations to search for! Will take 13.0 seconds to run.

# %%
def tryconvert(x):
        try:
            return geolocator.geocode(x).latitude
        except:
            return None

# %%
def tryconvertlong(x):
        try:
            return geolocator.geocode(x).longitude
        except:
            return None

# %%
locations_new["latitude"] = locations_new.locations.apply(lambda x: tryconvert(x))

# %%
locations_new["longitude"] = locations_new.locations.apply(lambda x: tryconvertlong(x))

# %%
countries = []
for row in locations_new.index:
    try:
        loc = geolocator.reverse([locations_new.iloc[row,1],locations_new.iloc[row,2]], language='en')
        countries.append(loc.raw['address']['country'])
    except:
        countries.append(None)

# %%
locations_new['country'] = countries

# %%
locations_new
# Out:
#                                 locations   latitude   longitude  \
# 0                  Costa Mesa, California  33.663339 -117.903317
# 1                        Bettendorf, Iowa  41.525276  -90.509639
# 2                       Odenton, Maryland  39.089720  -76.707353
# 3                        Fraser, Colorado  39.947286 -105.815423
# 4                Ridgefield , Connecticut  41.281484  -73.498179
# 5                   Boone, North Carolina  36.216795  -81.674552
# 6                         Wibaux, Montana  46.910018 -104.221517
# 7                Washngton, Washington DC        NaN         NaN
# 8                     Cape Coral, Florida  26.605943  -81.980677
# 9                  Goole, North Yorkshire  53.703562   -0.871595
# 10  Olsberg-Bigge, North Rhine-Westphalia  51.360750    8.483408
# 11                     Hallock, Minnesota  48.774426  -96.946447
# 12                 Glenside, Pennsylvania  40.102333  -75.152119
# 13                        Barberton, Ohio  41.012833  -81.605122
# 14                   Morrisville, Vermont  44.560939  -72.596396
# 15                  Rouyn-Noranda, Quebec  48.242052  -79.020538
# 16                        Sidmouth, Devon  50.679003   -3.237657
# 17                  New Prague, Minnesota  44.543333  -93.576044
# 18              Sneinton, Nottinghamshire  52.936484   -1.136763
# 19                  Yardley, Pennsylvania  40.245664  -74.845997
# 20       Hachenburg, Rhineland-Palatinate  50.662754    7.825317
# 21              Hemsworth, West Yorkshire  53.613163   -1.360180
# 22                     O’Fallon, Missouri  38.791037  -90.703911
# 23                    Firestone, Colorado  40.112484 -104.936644
# 24                   Winter Park, Florida  28.597771  -81.351026
# 25                 Barnetby, Lincolnshire  53.575013   -0.409761
#
#                      country
# 0   United States of America
# 1   United States of America
# 2   United States of America
# 3   United States of America
# 4   United States of America
# 5   United States of America
# 6   United States of America
# 7                       None
# 8   United States of America
# 9             United Kingdom
# 10                   Germany
# 11  United States of America
# 12  United States of America
# 13  United States of America
# 14  United States of America
# 15                    Canada
# 16            United Kingdom
# 17  United States of America
# 18            United Kingdom
# 19  United States of America
# 20                   Germany
# 21            United Kingdom
# 22  United States of America
# 23  United States of America
# 24  United States of America
# 25            United Kingdom

# %%
locations_df = pd.concat([locations_df,locations_new])
locations_df.to_csv('locations_geotagged.csv',index=False)

# %% [markdown]
# ## Merging and cleaning

# %%
beer_df
# Out:
#                                            return_string flag  \
# 0      St. Peter's Ruby Red Ale\n🇬🇧 Bitter - Ordinary...   🇬🇧
# 1      Shepherd Neame Spitfire (Bottle)\n🇬🇧 Bitter - ...   🇬🇧
# 2      Arbor Rocketman\n🇬🇧 IPA • 6.0%\n95\n97\n3.74\n...   🇬🇧
# 3      Shepherd Neame India Pale Ale (Bottle)\n🇬🇧 IPA...   🇬🇧
# 4      Shepherd Neame Christmas Ale\n🇬🇧 Strong Ale - ...   🇬🇧
# ...                                                  ...  ...
# 12914  Bad Joker Snail Trail\n🇺🇸 Blonde Ale / Golden ...   🇺🇸
# 12915  Soproni Radler Dark\n🇭🇺 Radler / Shandy\n-\n-\...   🇭🇺
# 12916  Black Oak Old Regular\n🇨🇦 Mild Ale\n-\n-\n3.50...   🇨🇦
# 12917  Breckenridge Oktoberfest\n🇺🇸 Märzen / Marzen /...   🇺🇸
# 12918  Three Heads Kind Kitty\n🇺🇸 IIPA DIPA - Imperia...   🇺🇸
#
#                                       type  abv rb_overall_score  \
# 0                Bitter - Ordinary / Best   4.3               49
# 1                Bitter - Ordinary / Best   4.5               34
# 2                                     IPA   6.0               95
# 3                           IPA - English   6.1               46
# 4                    Strong Ale - English   7.0               45
# ...                                    ...  ...              ...
# 12914             Blonde Ale / Golden Ale   5.1                -
# 12915                      Radler / Shandy  NaN                -
# 12916                             Mild Ale  NaN                -
# 12917   Märzen / Marzen / Oktoberfest Bier  0.0               57
# 12918    IIPA DIPA - Imperial / Double IPA  NaN                -
#
#       rb_style_score rb_user_rating  rb_rating_number  \
# 0                 95           3.25             415.0
# 1                 59           3.05            1083.0
# 2                 97           3.74              59.0
# 3                 47           3.22             420.0
# 4                 46           3.18             409.0
# ...              ...            ...               ...
# 12914              -           3.40               1.0
# 12915              -           2.90               1.0
# 12916              -           3.50               1.0
# 12917             94           3.59              12.0
# 12918              -           3.40               1.0
#
#                                    name_found
# 0                    St. Peter's Ruby Red Ale
# 1            Shepherd Neame Spitfire (Bottle)
# 2                             Arbor Rocketman
# 3      Shepherd Neame India Pale Ale (Bottle)
# 4                Shepherd Neame Christmas Ale
# ...                                       ...
# 12914                   Bad Joker Snail Trail
# 12915                     Soproni Radler Dark
# 12916                   Black Oak Old Regular
# 12917                Breckenridge Oktoberfest
# 12918                  Three Heads Kind Kitty
#
# [12919 rows x 9 columns]

# %%
# Creating DF with all details
df_all = pd.merge(df,locations_df,how='left',left_on='brewery_location',right_on='locations')
df_all = pd.merge(df_all, beer_df, how='left', left_on='beer_name',right_on='name_found')
df_all
# Out:
#                                         beer_name  beer_rating  \
# 0                        St. Peter's Ruby Red Ale          3.3
# 1                Shepherd Neame Spitfire (Bottle)          2.2
# 2                                 Arbor Rocketman          3.8
# 3          Shepherd Neame India Pale Ale (Bottle)          3.4
# 4                    Shepherd Neame Christmas Ale          3.3
# ...                                           ...          ...
# 23969                 Dogfish Head 120 Minute IPA          1.5
# 23970  Lagunitas Newcastle Brown Ale (US version)          1.0
# 23971                     Samuel Smiths India Ale          1.8
# 23972                       Big Smoke Cosmic Dawn          0.5
# 23973                           Bath Gem (Bottle)          1.6
#
#                brewery_location                            brewery_name  \
# 0               Bungay, Suffolk                     St. Peter's Brewery
# 1               Faversham, Kent                          Shepherd Neame
# 2      Bristol, Gloucestershire                              Arbor Ales
# 3               Faversham, Kent                          Shepherd Neame
# 4               Faversham, Kent                          Shepherd Neame
# ...                         ...                                     ...
# 23969                      -2.4  Dogfish Head Brewery (Boston Beer Co.)
# 23970                      -1.7    Lagunitas Brewing Company (Heineken)
# 23971                      -1.6                            Samuel Smith
# 23972                      -2.5                      Big Smoke Brew Co.
# 23973                      -1.5                 Bath Ales (St. Austell)
#
#                                           review_content        reviewer_name  \
# 0      Ruby color, offwhite coam. Aroma and taste: fl...            alex_leit
# 1      Disappointing show from the lads at ‘Britain’s...  shivermetimber.gray
# 2      Puszka. Mętne o żółtym kolorze. Piana biała,ob...              MarcinG
# 3      Bottle. Amber with bronze color and white foam...            alex_leit
# 4      Bottle. Aroma: English hops and malts with tof...            alex_leit
# ...                                                  ...                  ...
# 23969  0,3 litre Bottle from Total Wine And More, Lag...          ChrisOfstad
# 23970  Bottle from BevMo, Oceanside, Ca. Why is this ...          ChrisOfstad
# 23971  Bought Nov 8, 2019, at 'Gastronom', Izhevsk, R...             PastorGL
# 23972  On cask at Euston Tap. clear gold colour lasti...            harrisoni
# 23973  500ml bottle in 2015. I don’t know quite what ...                Beese
#
#                       locations   latitude  longitude         country  \
# 0               Bungay, Suffolk  52.456225   1.437341  United Kingdom
# 1               Faversham, Kent  51.314409   0.891189  United Kingdom
# 2      Bristol, Gloucestershire  51.852767  -2.255369  United Kingdom
# 3               Faversham, Kent  51.314409   0.891189  United Kingdom
# 4               Faversham, Kent  51.314409   0.891189  United Kingdom
# ...                         ...        ...        ...             ...
# 23969                      -2.4  48.800511   9.991238         Germany
# 23970                      -1.7  48.780313  10.039726         Germany
# 23971                      -1.6  48.718182   9.989251         Germany
# 23972                      -2.5  50.814444  14.361805  Czech Republic
# 23973                      -1.5  52.583680  13.276599         Germany
#
#                                            return_string flag  \
# 0      St. Peter's Ruby Red Ale\n🇬🇧 Bitter - Ordinary...   🇬🇧
# 1      Shepherd Neame Spitfire (Bottle)\n🇬🇧 Bitter - ...   🇬🇧
# 2      Arbor Rocketman\n🇬🇧 IPA • 6.0%\n95\n97\n3.74\n...   🇬🇧
# 3      Shepherd Neame India Pale Ale (Bottle)\n🇬🇧 IPA...   🇬🇧
# 4      Shepherd Neame Christmas Ale\n🇬🇧 Strong Ale - ...   🇬🇧
# ...                                                  ...  ...
# 23969  Dogfish Head 120 Minute IPA\n🇺🇸 IIPA DIPA - Im...   🇺🇸
# 23970  Lagunitas Newcastle Brown Ale (US version)\n🇺🇸...   🇺🇸
# 23971  Samuel Smiths India Ale\n🇬🇧 Bitter - Premium /...   🇬🇧
# 23972  Big Smoke Cosmic Dawn\n🇬🇧 Pale Ale - American ...   🇬🇧
# 23973  Bath Gem (Bottle)\n🇬🇧 Bitter - Premium / Stron...   🇬🇧
#
#                                       type   abv rb_overall_score  \
# 0                Bitter - Ordinary / Best    4.3               49
# 1                Bitter - Ordinary / Best    4.5               34
# 2                                     IPA    6.0               95
# 3                           IPA - English    6.1               46
# 4                    Strong Ale - English    7.0               45
# ...                                    ...   ...              ...
# 23969   IIPA DIPA - Imperial / Double IPA   16.5               99
# 23970                           Brown Ale    4.7               15
# 23971     Bitter - Premium / Strong / ESB    5.0               71
# 23972           Pale Ale - American / APA    4.1               29
# 23973     Bitter - Premium / Strong / ESB    4.8               40
#
#       rb_style_score rb_user_rating  rb_rating_number  \
# 0                 95           3.25             415.0
# 1                 59           3.05            1083.0
# 2                 97           3.74              59.0
# 3                 47           3.22             420.0
# 4                 46           3.18             409.0
# ...              ...            ...               ...
# 23969             98           3.93            2491.0
# 23970              9           1.47              10.0
# 23971             96           3.39            1694.0
# 23972             17           3.01              12.0
# 23973             51           3.15             303.0
#
#                                        name_found
# 0                        St. Peter's Ruby Red Ale
# 1                Shepherd Neame Spitfire (Bottle)
# 2                                 Arbor Rocketman
# 3          Shepherd Neame India Pale Ale (Bottle)
# 4                    Shepherd Neame Christmas Ale
# ...                                           ...
# 23969                 Dogfish Head 120 Minute IPA
# 23970  Lagunitas Newcastle Brown Ale (US version)
# 23971                     Samuel Smiths India Ale
# 23972                       Big Smoke Cosmic Dawn
# 23973                           Bath Gem (Bottle)
#
# [23974 rows x 19 columns]

# %%
# drop excess columns
df_all.drop(["locations","return_string","name_found"],axis=1,inplace=True)
# drop rows with ratings instead of location
df_all = df_all[~df_all['brewery_location'].str.len()<4]
# drop all NaNs
print(len(df_all) - len(df_all.dropna()), "columns with NaNs dropped.")
df_all.dropna(inplace=True)
# Out:
# 1752 columns with NaNs dropped.

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22222 entries, 0 to 23973
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   beer_name         22222 non-null  object
#  1   beer_rating       22222 non-null  float64
#  2   brewery_location  22222 non-null  object
#  3   brewery_name      22222 non-null  object
#  4   review_content    22222 non-null  object
#  5   reviewer_name     22222 non-null  object
#  6   latitude          22222 non-null  float64
#  7   longitude         22222 non-null  float64
#  8   country           22222 non-null  object
#  9   flag              22222 non-null  object
#  10  type              22222 non-null  object
#  11  abv               22222 non-null  float64
#  12  rb_overall_score  22222 non-null  object
#  13  rb_style_score    22222 non-null  object
#  14  rb_user_rating    22222 non-null  object
#  15  rb_rating_number  22222 non-null  float64
# dtypes: float64(5), object(11)
# memory usage: 2.9+ MB

# %% [markdown]
# ## Deal with Non-English Descriptions

# %% [markdown]
# ## Save down cleaned data

# %%
df_all.to_csv("data_clean.csv",index=False)

# %%
# Where the beers are from
plt.figure(figsize=(14,6))
ax = sns.barplot(x=locations_df.country.value_counts().head(15).index,y=locations_df.country.value_counts().head(15))
plt.setp(ax.get_xticklabels(), rotation=45)
plt.show()

# %%
plt.figure(figsize=(14,6))
ax = sns.swarmplot(data = df.groupby("reviewer_name").review_content.count())
plt.setp(ax.get_xticklabels(), rotation=45)
plt.show()

# %%
df.groupby("reviewer_name").review_content.count()
# Out:
# reviewer_name
# 101poodles       7
# 151rum           7
# 17Beer          30
# 2OLD4BS         25
# 2mutchbeer41     2
#                 ..
# zizzybalubba     6
# zombywoof        1
# zoucrew102      70
# zvikar          11
# zvsn            29
# Name: review_content, Length: 2390, dtype: int64

# %%
plt.figure(figsize=(12,12))
ax = sns.scatterplot(x=)
plt.show()
# Out:
#   File "<ipython-input-231-139d7ca9f737>", line 2
#     ax = sns.scatterplot(x=)
#                            ^
# SyntaxError: invalid syntax
