# %%
import pandas as pd
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas
from geopy.geocoders import Nominatim

# %% [markdown]
# ## Geotagging the scraped Data

# %%
df = pd.read_csv('all_reviews.csv')
locations_df = pd.read_csv('locations_geotagged.csv')
beer_df = pd.read_csv('beer_deets.csv')

# %%
df
# Out:
#                                                beer_name  beer_rating  \
# 0                               St. Peter's Ruby Red Ale          3.3
# 1                       Shepherd Neame Spitfire (Bottle)          2.2
# 2                                        Arbor Rocketman          3.8
# 3                 Shepherd Neame India Pale Ale (Bottle)          3.4
# 4                           Shepherd Neame Christmas Ale          3.3
# ...                                                  ...          ...
# 32278                          The Duck-Rabbit Brown Ale          1.2
# 32279                         Miller Genuine Draft (MGD)          4.4
# 32280  Gritty McDuffs Lions Pride Brown Ale (Best Bro...          5.0
# 32281                  New Holland Dragon's Milk - White          1.5
# 32282                      Bell's Double Two Hearted Ale          2.1
#
#                brewery_location                           brewery_name  \
# 0               Bungay, Suffolk                    St. Peter's Brewery
# 1               Faversham, Kent                         Shepherd Neame
# 2      Bristol, Gloucestershire                             Arbor Ales
# 3               Faversham, Kent                         Shepherd Neame
# 4               Faversham, Kent                         Shepherd Neame
# ...                         ...                                    ...
# 32278                        -2          The Duck-Rabbit Craft Brewery
# 32279                      +2.8  Miller Brewing Company (Molson Coors)
# 32280                      +2.2                         Gritty McDuffs
# 32281                      -1.8            New Holland Brewing Company
# 32282                      -1.6                         Bell's Brewery
#
#                                           review_content        reviewer_name
# 0      Ruby color, offwhite coam. Aroma and taste: fl...            alex_leit
# 1      Disappointing show from the lads at ‘Britain’s...  shivermetimber.gray
# 2      Puszka. Mętne o żółtym kolorze. Piana biała,ob...              MarcinG
# 3      Bottle. Amber with bronze color and white foam...            alex_leit
# 4      Bottle. Aroma: English hops and malts with tof...            alex_leit
# ...                                                  ...                  ...
# 32278  Got as a gift 6-pack. Sour, thin, over-carbona...            Intladvr1
# 32279  Great hot day refreshing lager,goes down smoot...           wootwoot83
# 32280  Very good brown ale. Big surprise to read the ...          jfsebastian
# 32281  Can from Total Wine in Sunnyvale, CA. Aroma is...           tightslice
# 32282  12oz bottle.  Pours a cloudy copper-gold with ...             tapefuzz
#
# [32283 rows x 6 columns]

# %%
locations_df
# Out:
#                                 locations   latitude  longitude  \
# 0                         Bungay, Suffolk  52.456225   1.437341
# 1                         Faversham, Kent  51.314409   0.891189
# 2                Bristol, Gloucestershire  51.852767  -2.255369
# 3                       Round Rock, Texas  30.508235 -97.678893
# 4                      Brooklyn, New York  40.650104 -73.949582
# ...                                   ...        ...        ...
# 2481           Rotherham, South Yorkshire  53.431042  -1.355187
# 2482                  Penn Yann, New York        NaN        NaN
# 2483           Tortworth, Gloucestershire  51.636745  -2.431266
# 2484                     Merzig, Saarland  49.442702   6.637490
# 2485  Hallerndorf-Stiebarlimbach, Bavaria  49.769856  10.947276
#
#                        country
# 0               United Kingdom
# 1               United Kingdom
# 2               United Kingdom
# 3     United States of America
# 4     United States of America
# ...                        ...
# 2481            United Kingdom
# 2482                       NaN
# 2483            United Kingdom
# 2484                   Germany
# 2485                   Germany
#
# [2486 rows x 4 columns]

# %%
geolocator = Nominatim(user_agent="None")

# %%
locations_new = pd.DataFrame(df.brewery_location[~df.brewery_location.isin(locations_df.locations)].unique(),columns=['locations'])
print(len(locations_new), "new locations to search for! Will take", len(locations_new)/2, "seconds to run.")
# Out:
# 31 new locations to search for! Will take 15.5 seconds to run.

# %%
def tryconvert(x):
        try:
            return geolocator.geocode(x).latitude
        except:
            return None

# %%
def tryconvertlong(x):
        try:
            return geolocator.geocode(x).longitude
        except:
            return None

# %%
locations_new["latitude"] = locations_new.locations.apply(lambda x: tryconvert(x))

# %%
locations_new["longitude"] = locations_new.locations.apply(lambda x: tryconvertlong(x))

# %%
countries = []
for row in locations_new.index:
    try:
        loc = geolocator.reverse([locations_new.iloc[row,1],locations_new.iloc[row,2]], language='en')
        countries.append(loc.raw['address']['country'])
    except:
        countries.append(None)

# %%
locations_new['country'] = countries

# %%
locations_new
# Out:
#                                 locations   latitude   longitude  \
# 0                     Huntsville, Alabama  34.729847  -86.585901
# 1                    Kingsport, Tennessee  36.550238  -82.559429
# 2                  Hammondsport, New York  42.407849  -77.223587
# 3                       Wetteren, Belgium  51.006880    3.885549
# 4                   Rock Island, Illinois  41.441179  -90.576614
# 5             Gaildorf, Baden-Württemberg  49.000260    9.769853
# 6                Little Eaton, Derbyshire  52.968932   -1.461467
# 7                     Workington, Cumbria  54.641572   -3.545929
# 8   Schweppenhausen, Rhineland-Palatinate  49.925908    7.800547
# 9                    Boca Raton , Florida  26.358688  -80.083098
# 10               Landsberg, Saxony-Anhalt  51.525376   12.162439
# 11                     Boisbriand, Quebec  45.613035  -73.838683
# 12                     Hannibal, Missouri  39.708250  -91.358741
# 13               Portsmouth, Rhode Island  41.602407  -71.250316
# 14                  Knoxville , Tennessee  35.960395  -83.921026
# 15                Fiskerton, Lincolnshire  53.235737   -0.427967
# 16           Parksville, British Columbia  49.317951 -124.311740
# 17            Horwich, Greater Manchester  53.596536   -2.540999
# 18                    St. Jacobs, Ontario  43.532949  -80.554627
# 19                    Corbyville, Ontario  44.220005  -77.389109
# 20                Pencombe, Herefordshire  52.171557   -2.588018
# 21          Creussen-Lindenhardt, Bavaria        NaN         NaN
# 22            Ordsall, Greater Manchester  53.469395   -2.277523
# 23                       Elveden, Suffolk  52.386576    0.678829
# 24                  Volendam, Netherlands  52.500514    5.077833
# 25                  Water Valley, Alberta  51.503892 -114.610937
# 26                          Humble, Texas  29.998831  -95.262155
# 27                         Acton, Ontario  43.634068  -80.035112
# 28                       Orillia, Ontario  44.609206  -79.417559
# 29                       Middletown, Ohio  39.515058  -84.398276
# 30                Welling, Greater London  51.465290    0.105904
#
#                      country
# 0   United States of America
# 1   United States of America
# 2   United States of America
# 3                    Belgium
# 4   United States of America
# 5                    Germany
# 6             United Kingdom
# 7             United Kingdom
# 8                    Germany
# 9   United States of America
# 10                   Germany
# 11                    Canada
# 12  United States of America
# 13  United States of America
# 14  United States of America
# 15            United Kingdom
# 16                    Canada
# 17            United Kingdom
# 18                    Canada
# 19                    Canada
# 20            United Kingdom
# 21                      None
# 22            United Kingdom
# 23            United Kingdom
# 24           The Netherlands
# 25                    Canada
# 26  United States of America
# 27                    Canada
# 28                    Canada
# 29  United States of America
# 30            United Kingdom

# %%
locations_df = pd.concat([locations_df,locations_new])
locations_df.to_csv('locations_geotagged.csv',index=False)

# %% [markdown]
# ## Merging and cleaning

# %%
beer_df
# Out:
#                                            return_string flag  \
# 0      St. Peter's Ruby Red Ale\n🇬🇧 Bitter - Ordinary...   🇬🇧
# 1      Shepherd Neame Spitfire (Bottle)\n🇬🇧 Bitter - ...   🇬🇧
# 2      Arbor Rocketman\n🇬🇧 IPA • 6.0%\n95\n97\n3.74\n...   🇬🇧
# 3      Shepherd Neame India Pale Ale (Bottle)\n🇬🇧 IPA...   🇬🇧
# 4      Shepherd Neame Christmas Ale\n🇬🇧 Strong Ale - ...   🇬🇧
# ...                                                  ...  ...
# 17143  Fort Orange Galactic Explosion\n🇺🇸 IPA - Hazy ...   🇺🇸
# 17144  Source Single Silo Series: Ultra Mosaic\n🇺🇸 II...   🇺🇸
# 17145  Yellowhammer Coffee Imperial Stout\n🇺🇸 Stout -...   🇺🇸
# 17146  Anyday ROSÉ\n🇺🇸 Apple Cider - Hopped / Malted ...   🇺🇸
# 17147  Stillmank Hazy Dayz IPA\n🇺🇸 IPA - Hazy / NEIPA...   🇺🇸
#
#                                         type  abv rb_overall_score  \
# 0                  Bitter - Ordinary / Best   4.3               49
# 1                  Bitter - Ordinary / Best   4.5               34
# 2                                       IPA   6.0               95
# 3                             IPA - English   6.1               46
# 4                      Strong Ale - English   7.0               45
# ...                                      ...  ...              ...
# 17143                    IPA - Hazy / NEIPA   6.3                -
# 17144       IIPA DIPA - Hazy / Double NEIPA   8.0                -
# 17145                      Stout - Imperial   8.0                -
# 17146   Apple Cider - Hopped / Malted / Graf  NaN                -
# 17147                     IPA - Hazy / NEIPA  NaN                -
#
#       rb_style_score rb_user_rating  rb_rating_number  \
# 0                 95           3.25             415.0
# 1                 59           3.05            1083.0
# 2                 97           3.74              59.0
# 3                 47           3.22             420.0
# 4                 46           3.18             409.0
# ...              ...            ...               ...
# 17143              -           4.00               1.0
# 17144              -           4.20               1.0
# 17145              -           3.10               1.0
# 17146              -           2.50               1.0
# 17147              -           3.30               1.0
#
#                                     name_found
# 0                     St. Peter's Ruby Red Ale
# 1             Shepherd Neame Spitfire (Bottle)
# 2                              Arbor Rocketman
# 3       Shepherd Neame India Pale Ale (Bottle)
# 4                 Shepherd Neame Christmas Ale
# ...                                        ...
# 17143           Fort Orange Galactic Explosion
# 17144  Source Single Silo Series: Ultra Mosaic
# 17145       Yellowhammer Coffee Imperial Stout
# 17146                              Anyday ROSÉ
# 17147                  Stillmank Hazy Dayz IPA
#
# [17148 rows x 9 columns]

# %%
# deal with the price issue
price_df = beer_df[beer_df.rb_overall_score.str.contains('Available')].copy()
beer_df = beer_df[~beer_df.rb_overall_score.str.contains('Available')]
price_df['rb_overall_score'] = price_df.return_string.apply(lambda x: x.split('\n')[3])
price_df['rb_style_score'] = price_df.return_string.apply(lambda x: x.split('\n')[4])
price_df['rb_user_rating'] = price_df.return_string.apply(lambda x: x.split('\n')[5])
price_df['rb_rating_number'] = price_df.return_string.apply(lambda x: x.split('\n')[6].replace("(","").replace(")",""))
beer_df = pd.concat([beer_df,price_df])
print("Number of issue beers sorted:", len(price_df))
# Out:
# Number of issue beers sorted: 291

# %%
# set the types to float (cant do for the overall score and rating as there are two many None "-")
beer_df.rb_user_rating = beer_df.rb_user_rating.astype(float)
beer_df.rb_rating_number = beer_df.rb_rating_number.astype(float)

# %%
# Creating DF with all details
df_all = pd.merge(df,locations_df,how='left',left_on='brewery_location',right_on='locations')
df_all = pd.merge(df_all, beer_df, how='left', left_on='beer_name',right_on='name_found')
df_all
# Out:
#                                                beer_name  beer_rating  \
# 0                               St. Peter's Ruby Red Ale          3.3
# 1                       Shepherd Neame Spitfire (Bottle)          2.2
# 2                                        Arbor Rocketman          3.8
# 3                 Shepherd Neame India Pale Ale (Bottle)          3.4
# 4                           Shepherd Neame Christmas Ale          3.3
# ...                                                  ...          ...
# 32590                          The Duck-Rabbit Brown Ale          1.2
# 32591                         Miller Genuine Draft (MGD)          4.4
# 32592  Gritty McDuffs Lions Pride Brown Ale (Best Bro...          5.0
# 32593                  New Holland Dragon's Milk - White          1.5
# 32594                      Bell's Double Two Hearted Ale          2.1
#
#                brewery_location                           brewery_name  \
# 0               Bungay, Suffolk                    St. Peter's Brewery
# 1               Faversham, Kent                         Shepherd Neame
# 2      Bristol, Gloucestershire                             Arbor Ales
# 3               Faversham, Kent                         Shepherd Neame
# 4               Faversham, Kent                         Shepherd Neame
# ...                         ...                                    ...
# 32590                        -2          The Duck-Rabbit Craft Brewery
# 32591                      +2.8  Miller Brewing Company (Molson Coors)
# 32592                      +2.2                         Gritty McDuffs
# 32593                      -1.8            New Holland Brewing Company
# 32594                      -1.6                         Bell's Brewery
#
#                                           review_content        reviewer_name  \
# 0      Ruby color, offwhite coam. Aroma and taste: fl...            alex_leit
# 1      Disappointing show from the lads at ‘Britain’s...  shivermetimber.gray
# 2      Puszka. Mętne o żółtym kolorze. Piana biała,ob...              MarcinG
# 3      Bottle. Amber with bronze color and white foam...            alex_leit
# 4      Bottle. Aroma: English hops and malts with tof...            alex_leit
# ...                                                  ...                  ...
# 32590  Got as a gift 6-pack. Sour, thin, over-carbona...            Intladvr1
# 32591  Great hot day refreshing lager,goes down smoot...           wootwoot83
# 32592  Very good brown ale. Big surprise to read the ...          jfsebastian
# 32593  Can from Total Wine in Sunnyvale, CA. Aroma is...           tightslice
# 32594  12oz bottle.  Pours a cloudy copper-gold with ...             tapefuzz
#
#                       locations   latitude  longitude         country  \
# 0               Bungay, Suffolk  52.456225   1.437341  United Kingdom
# 1               Faversham, Kent  51.314409   0.891189  United Kingdom
# 2      Bristol, Gloucestershire  51.852767  -2.255369  United Kingdom
# 3               Faversham, Kent  51.314409   0.891189  United Kingdom
# 4               Faversham, Kent  51.314409   0.891189  United Kingdom
# ...                         ...        ...        ...             ...
# 32590                        -2 -23.604131 -69.084278           Chile
# 32591                      +2.8  54.379170  10.982190         Germany
# 32592                      +2.2  48.793281   9.967117         Germany
# 32593                      -1.8  48.780981  10.037026         Germany
# 32594                      -1.6  48.718182   9.989251         Germany
#
#                                            return_string flag  \
# 0      St. Peter's Ruby Red Ale\n🇬🇧 Bitter - Ordinary...   🇬🇧
# 1      Shepherd Neame Spitfire (Bottle)\n🇬🇧 Bitter - ...   🇬🇧
# 2      Arbor Rocketman\n🇬🇧 IPA • 6.0%\n95\n97\n3.74\n...   🇬🇧
# 3      Shepherd Neame India Pale Ale (Bottle)\n🇬🇧 IPA...   🇬🇧
# 4      Shepherd Neame Christmas Ale\n🇬🇧 Strong Ale - ...   🇬🇧
# ...                                                  ...  ...
# 32590  The Duck-Rabbit Brown Ale\n🇺🇸 Brown Ale • 5.6%...   🇺🇸
# 32591  Miller Genuine Draft (MGD)\n🇺🇸 Pale Lager - No...   🇺🇸
# 32592  Gritty McDuffs Lions Pride Brown Ale (Best Bro...   🇺🇸
# 32593  New Holland Dragon's Milk - White\n🇺🇸 Stout • ...   🇺🇸
# 32594  Bell's Double Two Hearted Ale\n🇺🇸 IIPA DIPA - ...   🇺🇸
#
#                                           type   abv rb_overall_score  \
# 0                    Bitter - Ordinary / Best    4.3               49
# 1                    Bitter - Ordinary / Best    4.5               34
# 2                                         IPA    6.0               95
# 3                               IPA - English    6.1               46
# 4                        Strong Ale - English    7.0               45
# ...                                        ...   ...              ...
# 32590                               Brown Ale    5.6               49
# 32591   Pale Lager - North Am. / Light / Rice    4.7                0
# 32592                               Brown Ale    4.1               19
# 32593                                   Stout    6.0               65
# 32594       IIPA DIPA - Imperial / Double IPA   11.0               96
#
#       rb_style_score  rb_user_rating  rb_rating_number  \
# 0                 95            3.25             415.0
# 1                 59            3.05            1083.0
# 2                 97            3.74              59.0
# 3                 47            3.22             420.0
# 4                 46            3.18             409.0
# ...              ...             ...               ...
# 32590             64            3.24             514.0
# 32591              7            1.82            2199.0
# 32592             15            2.81             130.0
# 32593             60            3.38              77.0
# 32594             90            3.75             102.0
#
#                                               name_found
# 0                               St. Peter's Ruby Red Ale
# 1                       Shepherd Neame Spitfire (Bottle)
# 2                                        Arbor Rocketman
# 3                 Shepherd Neame India Pale Ale (Bottle)
# 4                           Shepherd Neame Christmas Ale
# ...                                                  ...
# 32590                          The Duck-Rabbit Brown Ale
# 32591                         Miller Genuine Draft (MGD)
# 32592  Gritty McDuffs Lions Pride Brown Ale (Best Bro...
# 32593                  New Holland Dragon's Milk - White
# 32594                      Bell's Double Two Hearted Ale
#
# [32595 rows x 19 columns]

# %%
# drop excess columns
df_all.drop(["locations","return_string","name_found"],axis=1,inplace=True)
# drop rows with ratings instead of location
print(len(df_all[df_all['brewery_location'].str.len()<4]),"columns without locations dropped.")
df_all = df_all[~df_all['brewery_location'].str.len()<4]
# drop all NaNs
print(len(df_all) - len(df_all.dropna()), "columns with NaNs dropped.")
df_all.dropna(inplace=True)
# Out:
# 221 columns without locations dropped.
# 2436 columns with NaNs dropped.

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30159 entries, 0 to 32594
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   beer_name         30159 non-null  object
#  1   beer_rating       30159 non-null  float64
#  2   brewery_location  30159 non-null  object
#  3   brewery_name      30159 non-null  object
#  4   review_content    30159 non-null  object
#  5   reviewer_name     30159 non-null  object
#  6   latitude          30159 non-null  float64
#  7   longitude         30159 non-null  float64
#  8   country           30159 non-null  object
#  9   flag              30159 non-null  object
#  10  type              30159 non-null  object
#  11  abv               30159 non-null  float64
#  12  rb_overall_score  30159 non-null  object
#  13  rb_style_score    30159 non-null  object
#  14  rb_user_rating    30159 non-null  float64
#  15  rb_rating_number  30159 non-null  float64
# dtypes: float64(6), object(10)
# memory usage: 3.9+ MB

# %% [markdown]
# ## Deal with Non-English Descriptions

# %% [markdown]
# ## Save down cleaned data

# %%
df_all.to_csv("data_clean.csv",index=False)
